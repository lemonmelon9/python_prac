# %%
from package_nanonis.nanonis_sxm import * #nanonis_sxm 로드
import numpy as np 
import matplotlib.pyplot as plt
from package_utils.cmap_custom import nanox

# %%
a = topography('Topo/TNS_STM6_#117_2938.sxm')
z_sublfxy = a.get_z('subtract linear fit xy')
plt.imshow(z_sublfxy, vmin = np.mean(z_sublfxy) - 3*np.std(z_sublfxy), vmax = np.mean(z_sublfxy) + 3*np.std(z_sublfxy), cmap = nanox()) 
cbar = plt.colorbar(location='right') #colormap 추가
cbar.set_label('Z')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
b = topography('Topo/TNS_STM6_#117_3782.sxm')
z = b.get_z('raw','bwd')*1e9
plt.imshow(z, vmin = np.mean(z) - 3*np.std(z), vmax = np.mean(z) + 3*np.std(z), cmap = nanox())
cbar = plt.colorbar(location='right') #colormap 추가
cbar.set_label('Z (nm)')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
c = currentmap('Topo/TNS_STM6_#117_3782.sxm')
i_c = c.get_map()
plt.imshow(i_c, vmin = np.mean(i_c) - 4*np.std(i_c), vmax = np.mean(i_c) + 4*np.std(i_c), cmap = nanox())
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
d = didvmap('Topo/TNS_STM6_#117_2938.sxm')
didv = d.get_map()
plt.imshow(didv, vmin = np.mean(didv) - 3*np.std(didv), vmax = np.mean(didv) + 3*np.std(didv), cmap = nanox())
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 2
#       1 d = didvmap('Topo/TNS_STM6_#117_2938.sxm')
# ----> 2 didv = d.get_map()
#       3 plt.imshow(didv, vmin = np.mean(didv) - 3*np.std(didv), vmax = np.mean(didv) + 3*np.std(didv), cmap = nanox())
#       4 plt.axis('off')
#
# File ~\Desktop\python 연습\package_nanonis\nanonis_sxm.py:233, in didvmap.get_map(self, scan_direction, channel)
#     231 def get_map(self, scan_direction = 'fwd', channel = 'LI_Demod_1_X'): # dI/dV 채널에서 가져오기
#     232     if scan_direction == 'fwd':
# --> 233         didv = self.signals[channel]['forward']
#     234     elif scan_direction == 'bwd':
#     235         import numpy as np
#
# KeyError: 'LI_Demod_1_X'

# %%
d.header
# Out:
# {'nanonis_version': '2',
#  'scanit_type': 'FLOAT            MSBFIRST',
#  'rec_date': '17.01.2024',
#  'rec_time': '14:18:56',
#  'rec_temp': '290.0000000000',
#  'acq_time': 550.6,
#  'scan_pixels': array([512, 512], dtype=int64),
#  'scan_file': 'D:\\Data\\(DW) Dowook Kim\\230922_TNS_STM6\\TNS_STM6_#117_2938.sxm',
#  'scan_time': array([0.5376, 0.5376]),
#  'scan_range': array([8.e-09, 8.e-09]),
#  'scan_offset': array([ 9.127599e-07, -1.045992e-06]),
#  'scan_angle': '-1.360E+2',
#  'scan_dir': 'up',
#  'bias': 0.45,
#  'z-controller': {'Name': ('log Current',),
#   'on': ('1',),
#   'Setpoint': ('2.000E-9 A',),
#   'P-gain': ('5.000E-12 m',),
#   'I-gain': ('7.000E-8 m/s',),
#   'T-const': ('7.143E-5 s',)},
#  'comment': '3 L TNS, LN2',
#  'nanonismain>session path': 'D:\\Data\\(DW) Dowook Kim\\230922_TNS_STM6',
#  'nanonismain>sw version': 'Generic 5',
#  'nanonismain>ui release': '13135',
#  'nanonismain>rt release': '13135',
#  'nanonismain>rt frequency (hz)': '20E+3',
# ...
