# %% [markdown]
# ## 이 파일은 cv2를 사용하지 않고 ndimage만을 사용하여 affine transformation을 했습니다.

# %%
from package_nanonis.nanonis_sxm import * 
import numpy as np 
import matplotlib.pyplot as plt
from package_utils.cmap_custom import nanox
from skimage.feature import peak_local_max
from skimage.io import imread # read/load the input image
from scipy import ndimage # affine transformation
from scipy.ndimage import gaussian_filter
from scipy.spatial import distance
import math

# %% [markdown]
# # Affine transformation for trianguler lattice

# %% [markdown]
# ### FFT

# %%
# Topography settings
topo = topography('Topo/Au111_W_LN2_0689.sxm')
topo1 = topo.get_z('subtract linear fit xy','fwd')

# Header
ScanPixels = topo.header['scan_pixels']
ScanRange = topo.header['scan_range']
ScanDir = str(topo.header['scan_dir']).lower()
if ScanDir == 'down':
        origin = 'upper'
elif ScanDir == 'up':
        origin = 'lower'

# plt settings
mm = 25.4
a = 100 / mm # width
b = 50 / mm # height
plt.rcParams['figure.figsize'] = (a,b)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 8
plt.rcParams['axes.xmargin'] = 0
# plt.rcParams['axes.ymargin'] = 0
fontsize=10

# FFT
topo1fft = fft.two_d_FFT_lin(topo1)
# topo1fft = fft.two_d_FFT_log(topo1)
# topo1fft = fft.two_d_FFT_sqrt(topo1)

# FFT image crop
center = round(ScanPixels[0]/2)
croppx = 30
topo1fftcrop = topo1fft[center-croppx:center+croppx, center-croppx:center+croppx]

# plot
fig, ax = plt.subplots(1,2)
sigma = 3
vmin = np.mean(topo1) - sigma*np.std(topo1)
vmax = np.mean(topo1) + sigma*np.std(topo1)
aspect = (ScanPixels[0]/ScanPixels[1])*(ScanRange[1]/ScanRange[0])
ax[0].imshow(topo1, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[0].axis('off')
ax[0].set_title('Topography', fontsize=8)

sigma = 30
vmin = np.mean(topo1fft) - sigma*np.std(topo1fft)
vmax = np.mean(topo1fft) + sigma*np.std(topo1fft)
ax[1].imshow(topo1fftcrop, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[1].axis('off')
ax[1].set_title('FFT', fontsize=8)

plt.tight_layout(pad=1)

# %% [markdown]
# ### Find local maximum peaks

# %%
topo1fftcrop_gaussian = gaussian_filter(topo1fftcrop, sigma=2)
min_distance = 7
lmax_coords = peak_local_max(topo1fftcrop_gaussian, min_distance=min_distance)
lmax_coords = np.delete(lmax_coords, [0], 0) # 중앙지점에 필요없는 peak 제거
print(lmax_coords)

fig, ax = plt.subplots(1, 2)

sigma = 10
vmin = np.nanmean(topo1fftcrop) - sigma*np.nanstd(topo1fftcrop) 
vmax = np.nanmean(topo1fftcrop) + sigma*np.nanstd(topo1fftcrop)
ax[0].imshow(topo1fftcrop, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[0].axis('off')

sigma = 5
vmin = np.nanmean(topo1fftcrop_gaussian) - sigma*np.nanstd(topo1fftcrop_gaussian) 
vmax = np.nanmean(topo1fftcrop_gaussian) + sigma*np.nanstd(topo1fftcrop_gaussian)
ax[1].imshow(topo1fftcrop_gaussian, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[1].plot(lmax_coords[:, 1], lmax_coords[:, 0], 'r.')
ax[1].axis('off')
# Out:
# [[15 18]
#  [45 42]
#  [34 11]
#  [26 49]
#  [11 37]
#  [49 23]]
# (-0.5, 59.5, 59.5, -0.5)

# %% [markdown]
# ### Affine transformation

# %%
# 원하는 peak 선택
wanted_list = [1,3,4]
lmax_coords_for_affine = lmax_coords[wanted_list]

fig, ax = plt.subplots(1,1)
ax.imshow(topo1fftcrop_gaussian, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax.plot(lmax_coords_for_affine[:, 1], lmax_coords_for_affine[:, 0], 'r.')
ax.axis('off')

# 좌표 center 맞추기 (center = [0,0])
lmax_coords_center = lmax_coords_for_affine-topo1fftcrop.shape[0]/2
print(lmax_coords_center)
# Out:
# [[ 15.  12.]
#  [ -4.  19.]
#  [-19.   7.]]

# %%
# 원점과 좌표들 사이의 mean distance
mean_r = []
for i in range(0,len(lmax_coords_center)):
    mean_r.append(distance.euclidean(lmax_coords_center[i], [0,0]))

print('distance:',mean_r)
mean_r = np.mean(mean_r, axis=0)
print('mean_r:',mean_r)
# Out:
# distance: [19.209372712298546, 19.4164878389476, 20.248456731316587]
# mean_r: 19.624772427520913

# %%
# peak position assigned
y1, x1 = lmax_coords_center[0]
y2, x2 = lmax_coords_center[1]
y3, x3 = lmax_coords_center[2]

# Slope of each peak positions
a1 = y1/x1

# Angle between positions calculated
theta_12 = math.atan(y1/x1) - math.atan(y2/x2)
theta_13 = math.atan(y1/x1) - math.atan(y3/x3)
print('theta_12:',theta_12*180/math.pi,'\ntheta_13 :',theta_13*180/math.pi)

# The new peak position calculated (distance between [0,0] & [x1_new,y1_new] = mean_r)
x1_new = np.sign(x1) * mean_r / math.sqrt(1 + a1**2)
y1_new = a1 * x1_new
print('x1_new :',x1_new, 'y1_new :', y1_new)

# Angle, the multiple of 60 degree
int_the_12 = round(theta_12*180/math.pi/60) 
int_the_13 = round(theta_13*180/math.pi/60)

# The slopes of a2 and a3 calculated
a2 = math.tan(math.atan(a1) - int_the_12 * math.pi/180 * 60)
a3 = math.tan(math.atan(a1) - int_the_13 * math.pi/180 * 60)

# The new peak positions (2th, 3rd) calculated ( the angle between [x1_new,y1_new] & [x2_new,y2_new] = int_the_12 * pi/3)
x2_new = np.sign(x2) * mean_r / math.sqrt(1 + a2**2)
y2_new = a2 * x2_new
print('x2_new :', x2_new, 'y2_new :', y2_new)

x3_new = np.sign(x3) * mean_r / math.sqrt(1 + a3**2)
y3_new = a3 * x3_new
print('x3_new :', x3_new, 'y3_new :', y3_new)
# Out:
# theta_12: 63.22884978553789
# theta_13 : 121.11533231474185
# x1_new : 12.25949814485493 y1_new : 15.324372681068663
# x2_new : 19.401045111293175 y2_new : -2.9548504905582345
# x3_new : 7.141546966438248 y3_new : -18.2792231716269

# %% [markdown]
# #### Affine matrix 구하는 함수

# %%
def calcAffineMatrix(sourcePoints, targetPoints):
    # For three or more source and target points, find the affine transformation
    A = []
    b = []
    for sp, trg in zip(sourcePoints, targetPoints):
        A.append([sp[0], 0, sp[1], 0, 1, 0])
        A.append([0, sp[0], 0, sp[1], 0, 1])
        b.append(trg[0])
        b.append(trg[1])
    result, resids, rank, s = np.linalg.lstsq(np.array(A), np.array(b),rcond=None)

    a0, a1, a2, a3, a4, a5 = result
    matrix = np.float32([[a0, a2, a4], [a1, a3, a5]])
    return matrix

# %%
# affine transformation using the new three peaks
rows, cols = ScanPixels

sr = [[x1, y1] ,[x2, y2] ,[x3, y3]]
target = [[x1_new, y1_new], [x2_new, y2_new], [x3_new, y3_new]]

# Affine transformation
matrix = calcAffineMatrix(sr, target)
topo1fft_affine = ndimage.affine_transform(topo1fft,matrix)

# %%
# 역격자 포인트 구하기
# 데이터 픽 좌표
x1_inv = y2-y3
y1_inv = -(x2-x3)
x2_inv = y3-y1
y2_inv = -(x3-x1)
x3_inv = y1-y2
y3_inv = -(x1-x2)

# 대칭성을 가지는 새로운 픽의 좌표
x1_new_inv = y2_new - y3_new
y1_new_inv = -(x2_new - x3_new)
x2_new_inv = y3_new - y1_new
y2_new_inv = -(x3_new - x1_new)
x3_new_inv = y1_new - y2_new
y3_new_inv = -(x1_new - x2_new)

# %%
# 기준 포인트 역격자에 해당하는 Affine transformation 구하기
# 전 후 좌표 변수 선언
sr_inv = [[x1_inv, y1_inv] ,[x2_inv, y2_inv] ,[x3_inv, y3_inv]]
target_inv = [[x1_new_inv, y1_new_inv], [x2_new_inv, y2_new_inv], [x3_new_inv, y3_new_inv]]

# affine matrix 구하고 real space 이미지에 적용하기
matrix_inv = calcAffineMatrix(sr_inv,target_inv)
topo1_affine = ndimage.affine_transform(topo1,matrix_inv)

print(matrix_inv)
# Out:
# [[ 9.8084468e-01 -5.0975174e-02 -7.8005094e-15]
#  [-3.5412438e-04  1.0211822e+00 -2.5919365e-15]]

# %%
fig, ax = plt.subplots(2,2,figsize = (6,5))

# Topo sigma
# cmap_topo = 'afmhot'
cmap_topo = nanox()
# cmap_topo = 'pink'
# cmap_topo = 'ocean'
sigma = 3
vmin = np.nanmean(topo1) - sigma*np.nanstd(topo1) # 3-sigma
vmax = np.nanmean(topo1) + sigma*np.nanstd(topo1)

center = round(ScanPixels[0]/2)
# croppx = 240
croppx = 256
topo1_crop = topo1[center-croppx:center+croppx, center-croppx:center+croppx] 
topo1_affine_crop = topo1_affine[center-croppx:center+croppx, center-croppx:center+croppx] 
ax[0,0].imshow(topo1_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_topo, aspect=aspect)
ax[1,0].imshow(topo1_affine_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_topo, aspect=aspect)

ax[0,0].axis('off')
ax[0,1].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')
ax[0,0].set_title('Topography: Raw', fontsize=8)
ax[0,1].set_title('FFT: Raw', fontsize=8)
ax[1,0].set_title('Topography: Affine', fontsize=8)
ax[1,1].set_title('FFT: Affine', fontsize=8)



# FFT sigma
# cmap_fft = 'Purples'
# cmap_fft = 'gist_gray'
cmap_fft = 'afmhot'
# cmap_fft = nanox()
sigma = 30
vmin = np.nanmean(topo1fft) - sigma*np.nanstd(topo1fft) 
vmax = np.nanmean(topo1fft) + sigma*np.nanstd(topo1fft)

# FFT image crop 
croppx = 28
# croppx = 256

center = round(ScanPixels[0]/2)
topo1fft_crop = topo1fft[center-croppx:center+croppx, center-croppx:center+croppx]

center = round(topo1_affine_crop.shape[0]/2)
# topo1fft_affine_crop = topo1fft_affine[center-croppx:center+croppx, center-croppx:center+croppx]
topo1fft_affine_crop = fft.two_d_FFT_lin(topo1_affine_crop)[center-croppx:center+croppx, center-croppx:center+croppx]

ax[0,1].imshow(topo1fft_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_fft, aspect=aspect)

sigma = 4
vmin = np.nanmean(topo1fft_affine_crop) - sigma*np.nanstd(topo1fft_affine_crop) 
vmax = np.nanmean(topo1fft_affine_crop) + sigma*np.nanstd(topo1fft_affine_crop)
ax[1,1].imshow(topo1fft_affine_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_fft, aspect=aspect)
# ax[1].set_title('linear fit (fast axis only)', fontsize=6)

plt.tight_layout(pad=1)

# %% [markdown]
# # Affine transformation for rectangular lattice

# %% [markdown]
# ### FFT

# %%
# Topography settings
topo = topography('Topo/Cu100_W_LN2_1686.sxm')
topo2 = topo.get_z('subtract linear fit xy','fwd')

# Header
ScanPixels = topo.header['scan_pixels']
ScanRange = topo.header['scan_range']
ScanDir = str(topo.header['scan_dir']).lower()
if ScanDir == 'down':
        origin = 'upper'
elif ScanDir == 'up':
        origin = 'lower'

# plt settings
mm = 25.4
a = 100 / mm # width
b = 50 / mm # height
plt.rcParams['figure.figsize'] = (a,b)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 8
plt.rcParams['axes.xmargin'] = 0
# plt.rcParams['axes.ymargin'] = 0
fontsize=10

# FFT
# topo2fft = fft.two_d_FFT_lin(topo2)
# topo2fft = fft.two_d_FFT_log(topo2)
topo2fft = fft.two_d_FFT_sqrt(topo2)

# FFT image crop
center = round(ScanPixels[0]/2)
croppx = 40
topo2fftcrop = topo2fft[center-croppx:center+croppx, center-croppx:center+croppx]

# plot
fig, ax = plt.subplots(1,2)
sigma = 3
vmin = np.mean(topo2) - sigma*np.std(topo2)
vmax = np.mean(topo2) + sigma*np.std(topo2)
aspect = (ScanPixels[0]/ScanPixels[1])*(ScanRange[1]/ScanRange[0])
ax[0].imshow(topo2, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[0].axis('off')
ax[0].set_title('Topography', fontsize=8)

sigma = 20
vmin = np.mean(topo2fft) - sigma*np.std(topo2fft)
vmax = np.mean(topo2fft) + sigma*np.std(topo2fft)
ax[1].imshow(topo2fftcrop, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[1].axis('off')
ax[1].set_title('FFT', fontsize=8)

plt.tight_layout(pad=1)

# %% [markdown]
# ### Find local maximum peaks

# %%
topo2fftcrop_gaussian = gaussian_filter(topo2fftcrop, sigma=1.2)
min_distance = 9
lmax_coords = peak_local_max(topo2fftcrop_gaussian, min_distance=min_distance)
lmax_coords = np.delete(lmax_coords, [4,5,6], 0) # 필요없는 peak 제거
print(lmax_coords)

fig, ax = plt.subplots(1, 2)

sigma = 10
vmin = np.nanmean(topo2fftcrop) - sigma*np.nanstd(topo2fftcrop) 
vmax = np.nanmean(topo2fftcrop) + sigma*np.nanstd(topo2fftcrop)
ax[0].imshow(topo2fftcrop, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[0].axis('off')

sigma = 5
vmin = np.nanmean(topo2fftcrop_gaussian) - sigma*np.nanstd(topo2fftcrop_gaussian) 
vmax = np.nanmean(topo2fftcrop_gaussian) + sigma*np.nanstd(topo2fftcrop_gaussian)
ax[1].imshow(topo2fftcrop_gaussian, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax[1].plot(lmax_coords[:, 1], lmax_coords[:, 0], 'r.')
ax[1].axis('off')
# Out:
# [[13 32]
#  [67 48]
#  [32 70]
#  [48 10]]
# (-0.5, 79.5, 79.5, -0.5)

# %% [markdown]
# ### Affine transformation

# %%
# 원하는 peak 선택
wanted_list = [0,2]
lmax_coords_for_affine = lmax_coords[wanted_list]

fig, ax = plt.subplots(1,1)
ax.imshow(topo2fftcrop_gaussian, origin=origin, vmin=vmin, vmax=vmax, cmap=nanox(), aspect=aspect)
ax.plot(lmax_coords_for_affine[:, 1], lmax_coords_for_affine[:, 0], 'r.')
ax.axis('off')

# 좌표 center 맞추기 (center = [0,0])
lmax_coords_center = lmax_coords_for_affine-topo2fftcrop.shape[0]/2
print(lmax_coords_center)
# Out:
# [[-27.  -8.]
#  [ -8.  30.]]

# %%
# 원점과 좌표들 사이의 mean distance
mean_r = []
for i in range(0,len(lmax_coords_center)):
    mean_r.append(distance.euclidean(lmax_coords_center[i], [0,0]))

print('distance:',mean_r)
mean_r = np.mean(mean_r, axis=0)
print('mean_r:',mean_r)
# Out:
# distance: [28.160255680657446, 31.04834939252005]
# mean_r: 29.604302536588747

# %%
# peak position assigned
y1, x1 = lmax_coords_center[0]
y2, x2 = lmax_coords_center[1]

print('x1: ', x1, 'y1: ', y1)
print('x2: ', x2, 'y2: ', y2)

# Slope of each peak positions
a1 = y1/x1

# Angle between positions calculated
theta_12 = math.atan(y1/x1) - math.atan(y2/x2)
print('theta_12:',theta_12*180/math.pi)

# The new peak position calculated (distance between [0,0] & [x1_new,y1_new] = mean_r)
x1_new = np.sign(x1) * mean_r / math.sqrt(1 + a1**2)
y1_new = a1 * x1_new
print('x1_new :',x1_new, 'y1_new :', y1_new)

# Angle, the multiple of 90 degree
int_the_12 = round(theta_12*180/math.pi/90) 

# The slopes of a2 and a3 calculated
a2 = math.tan(math.atan(a1) - int_the_12 * math.pi/180 * 90)

# The new peak positions calculated ( the angle between [x1_new,y1_new] & [x2_new,y2_new] = int_the_12 * pi/2)
x2_new = np.sign(x2) * mean_r / math.sqrt(1 + a2**2)
y2_new = a2 * x2_new
print('x2_new :', x2_new, 'y2_new :', y2_new)
# Out:
# x1:  -8.0 y1:  -27.0
# x2:  30.0 y2:  -8.0
# theta_12: 88.42705579638255
# x1_new : -8.410236859297603 y1_new : -28.384549400129412
# x2_new : 28.384549400129412 y2_new : -8.410236859297601

# %%
# Dummy points for rectangular lattice
y3, x3 = [0,0]
y3_new, x3_new = [0,0]

sr = sr = [[x1, y1] ,[x2, y2] ,[x3, y3]]
target = [[x1_new, y1_new], [x2_new, y2_new], [x3_new, y3_new]]

# Affine transformation
matrix = calcAffineMatrix(sr, target)
topo2fft_affine = ndimage.affine_transform(topo2fft,matrix)

# %%
# 역격자 포인트 구하기
# 데이터 픽 좌표
x1_inv = y2-y3
y1_inv = -(x2-x3)
x2_inv = y3-y1
y2_inv = -(x3-x1)
x3_inv = y1-y2
y3_inv = -(x1-x2)

# 대칭성을 가지는 새로운 픽의 좌표
x1_new_inv = y2_new - y3_new
y1_new_inv = -(x2_new - x3_new)
x2_new_inv = y3_new - y1_new
y2_new_inv = -(x3_new - x1_new)
x3_new_inv = y1_new - y2_new
y3_new_inv = -(x1_new - x2_new)

# %%
# 기준 포인트 역격자에 해당하는 Affine transformation 구하기
# 전 후 좌표 변수 선언
sr_inv = [[x1_inv, y1_inv] ,[x2_inv, y2_inv] ,[x3_inv, y3_inv]]
target_inv = [[x1_new_inv, y1_new_inv], [x2_new_inv, y2_new_inv], [x3_new_inv, y3_new_inv]]

# affine matrix 구하고 real space 이미지에 적용하기
matrix_inv = calcAffineMatrix(sr_inv,target_inv)
topo2_affine = ndimage.affine_transform(topo2,matrix_inv)

# %%
fig, ax = plt.subplots(2,2,figsize = (6,5))

# Topo sigma
# cmap_topo = 'afmhot'
cmap_topo = nanox()
# cmap_topo = 'pink'
# cmap_topo = 'ocean'
sigma = 3
vmin = np.nanmean(topo2) - sigma*np.nanstd(topo2) # 3-sigma
vmax = np.nanmean(topo2) + sigma*np.nanstd(topo2)

center = round(ScanPixels[0]/2)
# croppx = 240
croppx = 256
topo2_crop = topo2[center-croppx:center+croppx, center-croppx:center+croppx] 
topo2_affine_crop = topo2_affine[center-croppx:center+croppx, center-croppx:center+croppx] 
ax[0,0].imshow(topo2_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_topo, aspect=aspect)
ax[1,0].imshow(topo2_affine_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_topo, aspect=aspect)

ax[0,0].axis('off')
ax[0,1].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')
ax[0,0].set_title('Topography: Raw', fontsize=8)
ax[0,1].set_title('FFT: Raw', fontsize=8)
ax[1,0].set_title('Topography: Affine', fontsize=8)
ax[1,1].set_title('FFT: Affine', fontsize=8)



# FFT sigma
# cmap_fft = 'Purples'
# cmap_fft = 'gist_gray'
# cmap_fft = 'afmhot'
cmap_fft = nanox()
sigma = 30
vmin = np.nanmean(topo2fft) - sigma*np.nanstd(topo2fft) 
vmax = np.nanmean(topo2fft) + sigma*np.nanstd(topo2fft)

# FFT image crop 
croppx = 40
# croppx = 256

center = round(ScanPixels[0]/2)
topo2fft_crop = topo2fft[center-croppx:center+croppx, center-croppx:center+croppx]

center = round(topo2_affine_crop.shape[0]/2)
# topo1fft_affine_crop = topo1fft_affine[center-croppx:center+croppx, center-croppx:center+croppx]
topo2fft_affine_crop = fft.two_d_FFT_lin(topo2_affine_crop)[center-croppx:center+croppx, center-croppx:center+croppx]

ax[0,1].imshow(topo2fft_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_fft, aspect=aspect)

sigma = 4
vmin = np.nanmean(topo2fft_affine_crop) - sigma*np.nanstd(topo2fft_affine_crop) 
vmax = np.nanmean(topo2fft_affine_crop) + sigma*np.nanstd(topo2fft_affine_crop)
ax[1,1].imshow(topo2fft_affine_crop, origin=origin, vmin=vmin, vmax=vmax, cmap=cmap_fft, aspect=aspect)
# ax[1].set_title('linear fit (fast axis only)', fontsize=6)

plt.tight_layout(pad=1)
